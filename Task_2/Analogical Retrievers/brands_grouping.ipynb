# %%
import numpy as np
import pandas as pd
import json

# %%
df_new = pd.read_excel("content_simulation_test_company.xlsx")

# %%
df_new['inferred company'].unique()
# Out:
# array(['upmc', 'rbc', 'bbc', 'ucla', 'sky', 'coach', 'mars', 'ge',
#        'usaid', 'espn', 'jcb', 'unicef', 'express', 'sony', 'tam',
#        'indigo', 'chase', 'netflix', 'kfc', 'foot locker', 'house',
#        'diesel', 'cartier', 'airbnb', 'liverpool', 'finish line',
#        'burberry', 'bridgestone', 'philips', 'vodafone', 'rb', 'reliance',
#        'barclaycard', 'nordstrom', 'specsavers', 'bank of america',
#        'nike', 'zenith', 'best buy', 'bnp paribas', 'google', 'hampton',
#        'dell', 'wind', 'walgreens', 'flipkart', 'kaiser permanente',
#        'monster energy', 'optus', 'norwegian', 'panera bread', 'wrigley',
#        'logitech', 'air canada', 'skechers', 'brooks brothers',
#        'panasonic', 'aetna', 'klm',
#        'memorial sloan kettering cancer center', 'tripadvisor', 'safeway',
#        'river island', 'directv', 'mango', 'farmers insurance',
#        'walt disney world', 'gamestop', 'subway', 'engie',
# ...

# %%
li_new = df_new['inferred company'].unique().tolist()

# %%
with open("unseen_brands.json",'w') as file:
    json.dump(li_new, file)

# %%
df_old = pd.read_csv("train.csv")

# %%
li_old = df_old['inferred company'].unique().tolist()
li_old
# Out:
# ['tim hortons',
#  'independent',
#  'cbc',
#  'williams',
#  'cnn',
#  'cisco',
#  'getty images',
#  'mcafee',
#  'pfizer',
#  'toyota',
#  'bell',
#  'walmart',
#  'general motors',
#  'nokia',
#  'ups',
#  'hobby lobby',
#  'bacardi',
#  'amway',
#  'oracle',
#  'turkish airlines',
#  'shell',
#  'free',
#  'microsoft',
#  'cameron',
#  'united rentals',
#  'bayer',
#  'heineken',
#  'samsung',
#  'no',
#  'td',
#  'target',
#  'aaa',
#  'metro',
#  'ericsson',
#  'pepsico',
#  'avon',
#  'mtn',
#  'comcast',
#  'qatar airways',
#  'icici bank',
#  'rona',
#  'arm',
#  'amazon',
#  'emerson',
#  'asus',
#  'amc',
#  'little caesars pizza',
#  'staples',
#  'trane',
#  'national geographic',
#  'sabc',
#  'scotiabank',
#  'hudson',
#  'blackberry',
#  'padi',
#  'lane bryant',
#  'lenovo',
#  'bar',
#  'wwf',
#  'mastercard',
#  'spotify',
#  'groupon',
#  'red bull',
#  'greenpeace',
#  'harris teeter',
#  'paramount pictures',
#  'virgin media',
#  'urban outfitters',
# ...

# %%
with open("seen_brands.json",'w') as file:
    json.dump(li_old,file)

# %%
company_categories = [
    ['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'], # Broadcasting/Media
    ['Google', 'Microsoft', 'IBM', 'Oracle', 'Cisco', 'Amazon', 'Yahoo', 'Facebook', 'Instagram', 'Twitter'], # Technology/Internet
    ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis'], # Pharmaceuticals/Healthcare
    ['Toyota', 'General Motors', 'Nokia', 'Opel', 'Peugeot', 'Renault'], # Automobiles
    ['Air Canada', 'Turkish Airlines', 'Qatar Airways', 'United Airlines', 'Lufthansa', 'Ethiopian Airlines', 'Malaysia Airlines', 'Singapore Airlines', 'AirAsia'], # Airlines
    ['RBC', 'HSBC', 'Bank of America', 'Morgan Stanley', 'Goldman Sachs', 'ICICI Bank', 'Barclaycard', 'Chase', 'Bnp Paribas', 'Nordea', 'Wells Fargo', 'State Farm', 'Allstate', 'Charles Schwab', 'PNC', 'USAA', 'Metlife', 'Credit Suisse'], # Banks/Financial Services
    ['Target', 'Best Buy', 'Gamestop', 'Walmart', 'Macy', 'Nordstrom', 'Foot Locker', 'Finish Line', 'Neiman Marcus', 'Saks Fifth Avenue', 'Rite Aid', 'Office Depot', 'Dollar General', 'Meijer', 'Shoprite', 'Ulta Beauty'], # Retailers
    ['Shell', 'Total', 'BP'], # Energy
    ['Nike', 'Puma', 'Adidas', 'Ralph Lauren', 'Tommy Hilfiger', 'Lacoste', 'Hugo Boss', 'Converse', 'New Balance'], # Clothing / Footwear
    ['Netflix', 'Directv', 'Spotify', 'Walt Disney World', 'Paramount Pictures'], # Entertainment
    ['Airbnb', 'Tripadvisor', 'Booking.com'], # Travel Services
    ['Sony', 'Samsung', 'Panasonic', 'Logitech', 'HP', 'Dell', 'Lenovo', 'Asus', 'Acer', 'Motorola', 'LG Electronics', 'Hitachi'], # Electronics
    ['KFC', 'Subway', 'Chick-fil-A', 'Little Caesars Pizza', 'Pizza Hut', 'IHOP', 'Dairy Queen', 'Taco Bell'], # Fast Food
    ['Coach', 'Burberry', 'Cartier', 'Louis Vuitton', 'Gucci', 'Chanel'], # Luxury Brands
    ['Vodafone', 'Verizon', 'Airtel', 'Movistar'], # Telecommunications
    ['Unicef', 'WWF', 'Rotary International', 'YMCA'], # Non-profit Organizations
    ['Philips', 'GE', 'Siemens', 'Honeywell', 'Rockwell Automation'], # Industrial Companies
    ['Visa', 'Mastercard', 'American Express'], # Payment Systems
    ['Fedex', 'UPS'], # Courier Services
    ['Starbucks', 'Tim Hortons'], # Coffeehouse Chains
    ['Bridgestone', 'Michelin', 'Pirelli'], # Tire Manufacturers
    ['Monster Energy', 'Red Bull', 'PepsiCo'], # Beverage Companies
    ['US Army', 'GSA'], # Government Agencies
    ['Boeing', 'Airbus'], # Aerospace Companies
    ['Ebay', 'Flipkart'], # E-commerce
    ['Kaiser Permanente', 'Mayo Clinic', 'UCLA Health', 'Sutter Health'], # Healthcare Providers
    ['Farmers Insurance', 'American Family Insurance', 'Travelers'], # Insurance Companies
    ['Mars', 'General Mills', 'Sara Lee'], # Food Companies
    ['Lyft', 'Uber'], # Ride Sharing Companies
    ['Tesla', 'General Motors'], # Electric Vehicle Manufacturers
    ['Hertz', 'Avis'], # Car Rental Companies
    ['Home Depot', 'Lowe\'s'], # Home Improvement Stores
    ['Wrigley', 'Hershey'], # Confectionery Companies
    ['John Deere', 'Caterpillar'], # Heavy Equipment Manufacturers
    ['Amtrak', 'Virgin Trains'], # Train Companies
    ['SAP', 'Oracle'], # Enterprise Software Companies
    ['Western Union', 'PayPal'], # Money Transfer Companies
    ['AMD', 'Intel'], # Semiconductor Companies
    ['Accenture', 'Deloitte'], # Consulting Firms
    ['Unilever', 'Procter & Gamble'], # Consumer Goods Companies
    ['Comcast', 'AT&T'], # Telecommunications Companies
    ['McDonald\'s', 'Burger King'], # Fast Food Chains
    ['Coca-Cola', 'Pepsi'], # Beverage Companies
    ['Ford', 'Chevrolet'], # Automobile Manufacturers
    ['HSBC', 'Barclays'], # Banks
    ['Apple', 'Samsung'], # Technology Companies
    ['Nike', 'Adidas'], # Sportswear Brands
    ['Amazon', 'eBay'], # E-commerce Companies
    ['Microsoft', 'Apple'], # Technology Companies
    ['Visa', 'Mastercard'], # Financial Services Companies
    ['Pfizer', 'Johnson & Johnson'], # Pharmaceutical Companies
    ['ExxonMobil', 'Chevron'], # Oil Companies
    ['Walmart', 'Costco'], # Retail Companies
    ['Disney', 'Warner Bros.'], # Entertainment Companies
    ['FedEx', 'UPS'], # Delivery Services Companies
    ['General Electric', 'Siemens'], # Multinational Conglomerates
    ['IBM', 'HP'], # Technology Companies
    ['PepsiCo', 'The Coca-Cola Company'], # Beverage Companies
    ['Procter & Gamble', 'Unilever'], # Consumer Goods Companies
    ['Starbucks', 'Dunkin\' Donuts'], # Coffeehouse Chains
    ['Toyota', 'Honda'], # Automobile Manufacturers
    ['Vodafone', 'AT&T'], # Telecommunications Companies
    ['Walgreens', 'CVS Health'], # Pharmacy Chains
    ['Wells Fargo', 'JPMorgan Chase'], # Banks
    ['McDonald\'s', 'Yum! Brands'], # Fast Food Chains
    ['3M', 'Honeywell'], # Multinational Conglomerates
    ['Adobe', 'Microsoft'], # Software Companies
    ['Airbus', 'Boeing'], # Aerospace Companies
    ['Allianz', 'AXA'], # Insurance Companies
    ['Amazon', 'Alibaba Group'], # E-commerce Companies
    ['American Express', 'Visa'], # Financial Services Companies
    ['Apple', 'Samsung Electronics'], # Technology Companies
    ['AT&T', 'Verizon Communications'], # Telecommunications Companies
    ['Audi', 'BMW'], # Automobile Manufacturers
    ['Bank of America', 'Wells Fargo'], # Banks
    ['Bayer', 'Pfizer'], # Pharmaceutical Companies
    ['BMW', 'Mercedes-Benz'], # Automobile Manufacturers
    ['Boeing', 'Lockheed Martin'], # Aerospace Companies
    ['BP', 'Royal Dutch Shell'], # Oil Companies
    ['Bridgestone', 'Michelin'], # Tire Manufacturers
    ['Canon', 'Nikon'], # Camera Manufacturers
    ['Chevron', 'ExxonMobil'], # Oil Companies
    ['Cisco Systems', 'Juniper Networks'], # Networking Hardware Companies
    ['Coca-Cola', 'PepsiCo'], # Beverage Companies
    ['Comcast', 'The Walt Disney Company'], # Mass Media Companies
    ['Costco', 'Walmart'], # Retail Companies
    ['Dell', 'HP'], # Technology Companies
    ['DHL Express', 'FedEx'], # Delivery Services Companies
    ['Disney', 'Netflix'], # Entertainment Companies
    ['Dunkin\' Donuts', 'Starbucks'], # Coffeehouse Chains
    ['eBay', 'Amazon.com'], # E-commerce Companies
    ['ExxonMobil', 'BP'], # Oil Companies
    ['Facebook', 'Twitter'], # Social Media Companies
    ['FedEx', 'DHL Express'], # Delivery Services Companies
    ['Ford', 'General Motors'], # Automobile Manufacturers
    ['General Electric', '3M'], # Multinational Conglomerates
    ['General Motors', 'Ford'], # Automobile Manufacturers
    ['Google', 'Yahoo'], # Technology Companies
    ['H&M', 'Zara'], # Clothing Retail Companies
    ['Hewlett-Packard', 'IBM'], # Technology Companies
    ['Honda', 'Toyota'], # Automobile Manufacturers
    ['HSBC', 'Barclays'], # Banks
    ['Huawei', 'Samsung Electronics'], # Technology Companies
    ['Hyundai', 'Kia Motors'], # Automobile Manufacturers
    ['IBM', 'Microsoft'], # Technology Companies
    ['IKEA', 'Walmart'], # Retail Companies
    ['Intel', 'AMD'], # Semiconductor Companies
    ['JPMorgan Chase', 'Goldman Sachs'], # Banks
    ['KFC', 'McDonald\'s'], # Fast Food Chains
    ['Kia Motors', 'Hyundai'], # Automobile Manufacturers
    ['Lockheed Martin', 'Boeing'], # Aerospace Companies
    ['Louis Vuitton', 'Gucci'], # Luxury Brands
    ['MasterCard', 'Visa'], # Financial Services Companies
    ['McDonald\'s', 'Burger King'], # Fast Food Chains
    ['Mercedes-Benz', 'BMW'], # Automobile Manufacturers
    ['Microsoft', 'Apple'], # Technology Companies
    ['Nestle', 'The Coca-Cola Company'], # Food Processing Companies
    ['Netflix', 'Amazon.com'], # Entertainment Companies
    ['Nike', 'Adidas'], # Sportswear Brands
    ['Nikon', 'Canon'], # Camera Manufacturers
    ['Nintendo', 'Sony'], # Video Game Companies
    ['Nokia', 'Samsung Electronics'], # Technology Companies
    ['Oracle', 'SAP'], # Software Companies
    ['PepsiCo', 'Nestle'], # Food Processing Companies
    ['Pfizer', 'Johnson & Johnson'], # Pharmaceutical Companies
    ['Philips', 'Panasonic'], # Electronics Companies
    ['Pizza Hut', 'Domino\'s Pizza'], # Fast Food Chains
    ['Procter & Gamble', 'Unilever'], # Consumer Goods Companies
    ['Royal Dutch Shell', 'BP'], # Oil Companies
    ['Samsung Electronics', 'Apple'], # Technology Companies
    ['SAP', 'Oracle'], # Software Companies
    ['Siemens', 'General Electric'], # Multinational Conglomerates
    ['Sony', 'Nintendo'], # Video Game Companies
    ['Starbucks', 'McDonald\'s'], # Coffeehouse Chains
    ['Subway', 'McDonald\'s'], # Fast Food Chains
    ['The Coca-Cola Company', 'PepsiCo'], # Beverage Companies
    ['The Walt Disney Company', 'Comcast'], # Mass Media Companies
    ['Toyota', 'Ford'], # Automobile Manufacturers
    ['Twitter', 'Facebook'], # Social Media Companies
    ['Unilever', 'Procter & Gamble'], # Consumer Goods Companies
    ['Verizon Communications', 'AT&T'], # Telecommunications Companies
    ['Visa', 'MasterCard'], # Financial Services Companies
    ['Vodafone', 'Verizon Communications'], # Telecommunications Companies
    ['Volkswagen', 'Toyota'], # Automobile Manufacturers
    ['Walmart', 'Amazon.com'], # Retail Companies
    ['Wells Fargo', 'Bank of America'], # Banks
    ['Yahoo', 'Google'], # Technology Companies
    ['Zara', 'H&M'] # Clothing Retail Companies
]

# %%
arr=[]

# %%
for i in range(len(company_categories)):
    for j in range(len(company_categories[i])):
        if company_categories[i][j] not in arr:
            arr.append(company_categories[i][j])
        else:
            company_categories[i][j]=""

# %%
company_categories
# Out:
# [['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'],
#  ['Google',
#   'Microsoft',
#   'IBM',
#   'Oracle',
#   'Cisco',
#   'Amazon',
#   'Yahoo',
#   'Facebook',
#   'Instagram',
#   'Twitter'],
#  ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis'],
#  ['Toyota', 'General Motors', 'Nokia', 'Opel', 'Peugeot', 'Renault'],
#  ['Air Canada',
#   'Turkish Airlines',
#   'Qatar Airways',
#   'United Airlines',
#   'Lufthansa',
#   'Ethiopian Airlines',
#   'Malaysia Airlines',
#   'Singapore Airlines',
#   'AirAsia'],
#  ['RBC',
#   'HSBC',
#   'Bank of America',
#   'Morgan Stanley',
#   'Goldman Sachs',
#   'ICICI Bank',
#   'Barclaycard',
#   'Chase',
#   'Bnp Paribas',
#   'Nordea',
#   'Wells Fargo',
#   'State Farm',
#   'Allstate',
#   'Charles Schwab',
#   'PNC',
#   'USAA',
#   'Metlife',
#   'Credit Suisse'],
#  ['Target',
#   'Best Buy',
#   'Gamestop',
#   'Walmart',
#   'Macy',
#   'Nordstrom',
#   'Foot Locker',
#   'Finish Line',
# ...

# %%
result = [[element for element in sublist if element != ""] for sublist in company_categories]
result2 = [sublist for sublist in result if sublist]

# %%
result2
# Out:
# [['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'],
#  ['Google',
#   'Microsoft',
#   'IBM',
#   'Oracle',
#   'Cisco',
#   'Amazon',
#   'Yahoo',
#   'Facebook',
#   'Instagram',
#   'Twitter'],
#  ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis'],
#  ['Toyota', 'General Motors', 'Nokia', 'Opel', 'Peugeot', 'Renault'],
#  ['Air Canada',
#   'Turkish Airlines',
#   'Qatar Airways',
#   'United Airlines',
#   'Lufthansa',
#   'Ethiopian Airlines',
#   'Malaysia Airlines',
#   'Singapore Airlines',
#   'AirAsia'],
#  ['RBC',
#   'HSBC',
#   'Bank of America',
#   'Morgan Stanley',
#   'Goldman Sachs',
#   'ICICI Bank',
#   'Barclaycard',
#   'Chase',
#   'Bnp Paribas',
#   'Nordea',
#   'Wells Fargo',
#   'State Farm',
#   'Allstate',
#   'Charles Schwab',
#   'PNC',
#   'USAA',
#   'Metlife',
#   'Credit Suisse'],
#  ['Target',
#   'Best Buy',
#   'Gamestop',
#   'Walmart',
#   'Macy',
#   'Nordstrom',
#   'Foot Locker',
#   'Finish Line',
# ...

# %%
new_list = [sublist.pop() for sublist in result2 if len(sublist) == 1]

# %%
len(new_list)
# Out:
# 34

# %%
new_list
# Out:
# ['Tesla',
#  'SAP',
#  'Barclays',
#  'Apple',
#  'eBay',
#  'Johnson & Johnson',
#  'Costco',
#  'FedEx',
#  'General Electric',
#  'The Coca-Cola Company',
#  "Dunkin' Donuts",
#  'Honda',
#  'CVS Health',
#  'JPMorgan Chase',
#  'Yum! Brands',
#  '3M',
#  'Adobe',
#  'Alibaba Group',
#  'Samsung Electronics',
#  'Verizon Communications',
#  'Mercedes-Benz',
#  'Lockheed Martin',
#  'Royal Dutch Shell',
#  'The Walt Disney Company',
#  'DHL Express',
#  'Amazon.com',
#  'Hewlett-Packard',
#  'Huawei',
#  'IKEA',
#  'MasterCard',
#  'Nestle',
#  'Nintendo',
#  "Domino's Pizza",
#  'Volkswagen']

# %%
result2
# Out:
# [['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'],
#  ['Google',
#   'Microsoft',
#   'IBM',
#   'Oracle',
#   'Cisco',
#   'Amazon',
#   'Yahoo',
#   'Facebook',
#   'Instagram',
#   'Twitter'],
#  ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis'],
#  ['Toyota', 'General Motors', 'Nokia', 'Opel', 'Peugeot', 'Renault'],
#  ['Air Canada',
#   'Turkish Airlines',
#   'Qatar Airways',
#   'United Airlines',
#   'Lufthansa',
#   'Ethiopian Airlines',
#   'Malaysia Airlines',
#   'Singapore Airlines',
#   'AirAsia'],
#  ['RBC',
#   'HSBC',
#   'Bank of America',
#   'Morgan Stanley',
#   'Goldman Sachs',
#   'ICICI Bank',
#   'Barclaycard',
#   'Chase',
#   'Bnp Paribas',
#   'Nordea',
#   'Wells Fargo',
#   'State Farm',
#   'Allstate',
#   'Charles Schwab',
#   'PNC',
#   'USAA',
#   'Metlife',
#   'Credit Suisse'],
#  ['Target',
#   'Best Buy',
#   'Gamestop',
#   'Walmart',
#   'Macy',
#   'Nordstrom',
#   'Foot Locker',
#   'Finish Line',
# ...

# %%
result3 = [sublist for sublist in result2 if sublist]
result3
# Out:
# [['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'],
#  ['Google',
#   'Microsoft',
#   'IBM',
#   'Oracle',
#   'Cisco',
#   'Amazon',
#   'Yahoo',
#   'Facebook',
#   'Instagram',
#   'Twitter'],
#  ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis'],
#  ['Toyota', 'General Motors', 'Nokia', 'Opel', 'Peugeot', 'Renault'],
#  ['Air Canada',
#   'Turkish Airlines',
#   'Qatar Airways',
#   'United Airlines',
#   'Lufthansa',
#   'Ethiopian Airlines',
#   'Malaysia Airlines',
#   'Singapore Airlines',
#   'AirAsia'],
#  ['RBC',
#   'HSBC',
#   'Bank of America',
#   'Morgan Stanley',
#   'Goldman Sachs',
#   'ICICI Bank',
#   'Barclaycard',
#   'Chase',
#   'Bnp Paribas',
#   'Nordea',
#   'Wells Fargo',
#   'State Farm',
#   'Allstate',
#   'Charles Schwab',
#   'PNC',
#   'USAA',
#   'Metlife',
#   'Credit Suisse'],
#  ['Target',
#   'Best Buy',
#   'Gamestop',
#   'Walmart',
#   'Macy',
#   'Nordstrom',
#   'Foot Locker',
#   'Finish Line',
# ...

# %%
l = 0
for i in result3:
    l+=len(i)

l
# Out:
# 203

# %%
with open("company_groups.txt",'w') as file:
    for li in result3:
        file.write(str(li)+'\n')

# %%
dict = {
    'Broadcasting': ['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'],
    'Software Giants': ['Adobe', 'Apple', 'Google', 'Microsoft', 'IBM', 'Oracle', 'Cisco', 'Amazon', 'Yahoo', 'Facebook', 'Instagram', 'Twitter'],
    'Software': ['Cisco Systems', 'Juniper Networks','SAP'],
    'Pharmaceuticals': ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis','Johnson & Johnson'],
    'Automotive': ['Volkswagen', 'Mercedes-Benz', 'Toyota', 'General Motors', 'Opel', 'Peugeot', 'Renault','Ford', 'Chevrolet', 'Audi', 'BMW', 'Tesla', 'Hyundai', 'Kia Motors', 'Honda'],
    'Airlines': ['Air Canada', 'Turkish Airlines', 'Qatar Airways', 'United Airlines', 'Lufthansa', 'Ethiopian Airlines', 'Malaysia Airlines', 'Singapore Airlines', 'AirAsia'],
    'Banks': ['RBC', 'HSBC', 'Bank of America', 'JPMorgan Chase', 'Morgan Stanley', 'Goldman Sachs', 'ICICI Bank', 'Barclaycard', 'Chase', 'Bnp Paribas', 'Nordea', 'Wells Fargo', 'State Farm', 'Allstate', 'Charles Schwab', 'PNC', 'USAA', 'Metlife', 'Credit Suisse', 'Allianz', 'AXA'],
    'Retail': ['Target', 'Best Buy', 'Gamestop','Foot Locker', 'Neiman Marcus', 'Saks Fifth Avenue', 'Rite Aid', 'Office Depot', 'Dollar General', 'Meijer', 'Ulta Beauty'],
    'Supermarkets': ['Walmart', 'Costco', 'Shoprite', 'Macy', 'Nordstrom', 'Finish Line'],
    'Oil and Gas': ['Shell', 'Total', 'BP', 'ExxonMobil', 'Chevron'],
    'Clothing': ['Nike', 'Puma', 'Adidas', 'Ralph Lauren', 'Tommy Hilfiger', 'Lacoste', 'Hugo Boss', 'Converse', 'New Balance','H&M', 'Zara'],
    'Entertainment': ['Netflix', 'Directv', 'Spotify', 'Walt Disney World', 'Paramount Pictures'],
    'Travel': ['Airbnb', 'Tripadvisor', 'Booking.com'],
    'Electronics and Hardware': ['Hewlett-Packard', 'Nokia', 'Nintendo', 'Huawei', 'Samsung Electronics', 'Sony', 'Samsung', 'Panasonic', 'Logitech', 'HP', 'Dell', 'Lenovo', 'Asus', 'Acer', 'Motorola', 'LG Electronics', 'Hitachi'],
    'Fast Food': ["Domino's Pizza", 'Yum! Brands', 'KFC', 'Subway', 'Chick-fil-A', 'Little Caesars Pizza', 'Pizza Hut', 'IHOP', 'Dairy Queen', 'Taco Bell',"McDonald's", 'Burger King'],
    'Luxury Brands': ['Coach', 'Burberry', 'Cartier', 'Louis Vuitton', 'Gucci', 'Chanel'],
    'Telecommunications': ['Vodafone', 'Verizon', 'Airtel', 'Movistar','Comcast', 'AT&T'],
    'Worldwide Associations': ['Unicef', 'WWF', 'Rotary International', 'YMCA'],
    'Electrical Appliances': ['Philips', 'GE', 'Siemens', 'Honeywell', 'Rockwell Automation'],
    'Credit Card': ['Visa', 'Mastercard', 'American Express'],
    'Transport': ['Fedex', 'UPS', 'DHL Express'],
    'Coffeehouses': ['Starbucks', 'Tim Hortons', "Dunkin' Donuts"],
    'Tire Manufacturers': ['Bridgestone', 'Michelin', 'Pirelli'],
    'Energy/Soft Drinks': ['Monster Energy', 'Red Bull', 'PepsiCo','Coca-Cola', 'Pepsi'],
    'Defense': ['US Army', 'GSA', 'Lockheed Martin'],
    'Airplane Manufacturers': ['Boeing', 'Airbus'],
    'Online Commerce': ['Amazon.com', 'Alibaba Group', 'Ebay', 'Flipkart'],
    'Healthcare': ['CVS Health', 'Kaiser Permanente', 'Mayo Clinic', 'UCLA Health', 'Sutter Health'],
    'Insurance': ['Farmers Insurance', 'American Family Insurance', 'Travelers'],
    'Food Company': ['Nestle', 'Mars', 'General Mills', 'Sara Lee'],
    'Taxi': ['Lyft', 'Uber'],
    'Car Rental': ['Hertz', 'Avis'],
    'Home Improvement': ['Home Depot', "Lowe's"],
    'Candy': ['Wrigley', 'Hershey'],
    'Big Machinery': ['John Deere', 'Caterpillar'],
    'Trains': ['Amtrak', 'Virgin Trains'],
    'Money Transfers': ['Western Union', 'PayPal'],
    'Microprocessors': ['AMD', 'Intel'],
    'Consulting': ['Accenture', 'Deloitte'],
    'Consumer Goods Companies': ['Unilever', 'Procter & Gamble'],
    'Entertainment Production Companies': ['Disney', 'Warner Bros.'],
    'Camera': ['Canon', 'Nikon'],
    '3M': ['3M']
}

# %%
companies_dict = {
    'Broadcasting': ['bbc', 'cbc', 'espn', 'sky', 'cnn', 'independent', 'national geographic'],
    'Software Giants': ['adobe', 'apple', 'google', 'microsoft', 'ibm', 'oracle', 'cisco', 'amazon', 'yahoo', 'facebook', 'instagram', 'twitter'],
    'Software': ['juniper networks','sap'],
    'Pharmaceuticals': ['UCLA','UPMC','RB','Aetna','Memorial SLoan Kettering Cancer center','walgreens', 'cvs pharmacy', 'pfizer', 'bayer', 'novartis','johnson & johnson'],
    'Automotive': ['volkswagen', 'mercedes-benz', 'toyota', 'general motors', 'opel', 'peugeot', 'renault','ford', 'chevrolet', 'audi', 'bmw', 'tesla', 'hyundai', 'kia motors', 'honda'],
    'Airlines': ['Indigo','TAM','Norwegian','KLM','air canada', 'turkish airlines', 'qatar airways', 'united airlines', 'lufthansa', 'ethiopian airlines', 'malaysia airlines', 'singapore airlines', 'airasia'],
    'Banks': ['rbc', 'hsbc', 'bank of america', 'jpmorgan chase', 'morgan stanley', 'goldman sachs', 'icici bank', 'barclaycard', 'chase', 'bnp paribas', 'nordea', 'wells fargo', 'state farm', 'allstate', 'charles schwab', 'pnc', 'usaa', 'metlife', 'credit suisse', 'allianz', 'axa'],
    'Retail': ['Express','Specsavers','mango','river island','Carrefour','Argos','REI','target', 'best buy', 'gamestop','foot locker', 'neiman marcus', 'saks fifth avenue', 'rite aid', 'office depot', 'dollar general', 'meijer', 'ulta beauty'],
    'Supermarkets': ['kroger','walmart', 'costco', 'shoprite', 'macy', 'nordstrom', 'finish line'],
    'Oil and Gas': ['engie',"EDF",'shell', 'total', 'bp', 'exxonmobil', 'chevron'],
    'Clothing': ['Liverpool','Diesel','Brook Brothers','Skechers','nike', 'puma', 'adidas', 'ralph lauren', 'tommy hilfiger', 'lacoste', 'hugo boss', 'converse', 'new balance','h&m', 'zara'],
    'Entertainment': ['netflix', 'directv', 'spotify', 'walt disney world', 'paramount pictures'],
    'Travel': ['Club Med','airbnb', 'tripadvisor', 'booking.com'],
    'Electronics and Hardware': ['hewlett-packard', 'nokia', 'nintendo', 'huawei', 'samsung electronics', 'sony', 'samsung', 'panasonic', 'logitech', 'hp', 'dell', 'lenovo', 'asus', 'acer', 'motorola', 'lg electronics', 'hitachi'],
    'Fast Food': ["Panera Bread","domino's pizza", 'yum! brands', 'kfc', 'subway', 'chick-fil-a', 'little caesars pizza', 'pizza hut', 'ihop', 'dairy queen', 'taco bell',"mcdonald's", 'burger king'],
    'Luxury Brands': ['coach', 'burberry', 'cartier', 'louis vuitton', 'gucci', 'chanel'],
    'Telecommunications': ["optus",'wind','vodafone', 'verizon', 'airtel', 'movistar','comcast', 'at&t'],
    'Worldwide Associations': ['unicef', 'wwf', 'rotary international', 'ymca'],
    'Electrical Appliances': ['Zenith','philips', 'ge', 'siemens', 'honeywell', 'rockwell automation'],
    'Credit Card': ['visa', 'mastercard', 'american express'],
    'Transport': ['fedex', 'ups', 'dhl express'],
    'Coffeehouses': ['starbucks', 'tim hortons', "dunkin' donuts"],
    'Tire Manufacturers': ['bridgestone', 'michelin', 'pirelli'],
    'Energy/Soft Drinks': ['monster energy', 'red bull', 'pepsico','coca-cola', 'pepsi'],
    'Defense': ['us army', 'gsa', 'lockheed martin'],
    'Airplane Manufacturers': ['boeing', 'airbus'],
    'Online Commerce': ['amazon.com', 'alibaba group', 'ebay', 'flipkart'],
    'Healthcare': ['cvs health', 'kaiser permanente', 'mayo clinic', 'ucla health', 'sutter health'],
    'Insurance': ['farmers insurance', 'american family insurance', 'travelers'],
    'Food Company': ['nestle', 'mars', 'general mills', 'sara lee'],
    'Taxi': ['lyft', 'uber'],
    'Car Rental': ['hertz', 'avis'],
    'Home Improvement': ['home depot', "lowe's"],
    'Real estate': ['Coldwell Banker','House'],
    'Candy': ['wrigley', 'hershey'],
    'Big Machinery': ['john deere', 'caterpillar'],
    'Trains': ['amtrak', 'virgin trains'],
    'Money Transfers': ['western union', 'paypal'],
    'Microprocessors': ['amd', 'intel'],
    'Consulting': ['accenture', 'deloitte'],
    'Consumer Goods Companies': ['unilever', 'procter & gamble'],
    'Entertainment Production Companies': ['disney', 'warner bros.'],
    'Camera': ['canon', 'nikon'],
    'conglomerate':['Reliance'],
    'Hotels':["Hampton"],
    '3M': ['3m'],
    'Construction':["JCB"],
    'NGO':["USAID"]
}
# Out:
# ['bbc', 'cbc', 'espn', 'sky', 'cnn', 'independent', 'national geographic']
# ['adobe', 'apple', 'google', 'microsoft', 'ibm', 'oracle', 'cisco', 'amazon', 'yahoo', 'facebook', 'instagram', 'twitter']

# %%
values_list=[]
for values in companies_dict.values():
    values_list+=(values)

# Print the list
print(values_list)
# Out:
# ['bbc', 'cbc', 'espn', 'sky', 'cnn', 'independent', 'national geographic', 'adobe', 'apple', 'google', 'microsoft', 'ibm', 'oracle', 'cisco', 'amazon', 'yahoo', 'facebook', 'instagram', 'twitter', 'juniper networks', 'sap', 'walgreens', 'cvs pharmacy', 'pfizer', 'bayer', 'novartis', 'johnson & johnson', 'volkswagen', 'mercedes-benz', 'toyota', 'general motors', 'opel', 'peugeot', 'renault', 'ford', 'chevrolet', 'audi', 'bmw', 'tesla', 'hyundai', 'kia motors', 'honda', 'air canada', 'turkish airlines', 'qatar airways', 'united airlines', 'lufthansa', 'ethiopian airlines', 'malaysia airlines', 'singapore airlines', 'airasia', 'rbc', 'hsbc', 'bank of america', 'jpmorgan chase', 'morgan stanley', 'goldman sachs', 'icici bank', 'barclaycard', 'chase', 'bnp paribas', 'nordea', 'wells fargo', 'state farm', 'allstate', 'charles schwab', 'pnc', 'usaa', 'metlife', 'credit suisse', 'allianz', 'axa', 'target', 'best buy', 'gamestop', 'foot locker', 'neiman marcus', 'saks fifth avenue', 'rite aid
# ...

# %%
df_values_list = df_new['inferred company'].unique().tolist()

# Identify values not present in values_list
not_in_values_list = [value for value in df_values_list if value not in values_list]

# Print the values not in values_list
print("Values not in values_list:")
for value in not_in_values_list:
    print(value)
# Out:
# Values not in values_list:
# upmc
# ucla
# usaid
# jcb
# express
# tam
# indigo
# house
# diesel
# liverpool
# rb
# reliance
# specsavers
# zenith
# hampton
# wind
# optus
# norwegian
# panera bread
# skechers
# brooks brothers
# aetna
# klm
# memorial sloan kettering cancer center
# safeway
# river island
# mango
# engie
# coldwell banker
# kroger
# argos
# carrefour
# lidl
# edf
# club med
# rei

# %%
companies = [
    # Broadcasting
    ['BBC', 'CBC', 'ESPN', 'Sky', 'CNN', 'Independent', 'National Geographic'],
    
    # Software giants
    ['Adobe', 'Apple', 'Google', 'Microsoft', 'IBM', 'Oracle', 'Cisco', 'Amazon', 'Yahoo', 'Facebook', 'Instagram', 'Twitter'],
    
    # Software
    ['Cisco Systems', 'Juniper Networks', 'SAP'],
    
    # Pharmaceuticals
    ['Walgreens', 'CVS Pharmacy', 'Pfizer', 'Bayer', 'Novartis', 'Johnson & Johnson'],
    
    # Automotive
    ['Volkswagen', 'Mercedes-Benz', 'Toyota', 'General Motors', 'Opel', 'Peugeot', 'Renault', 'Ford', 'Chevrolet', 'Audi', 'BMW', 'Tesla', 'Hyundai', 'Kia Motors', 'Honda'],
    
    # Airlines
    ['Air Canada', 'Turkish Airlines', 'Qatar Airways', 'United Airlines', 'Lufthansa', 'Ethiopian Airlines', 'Malaysia Airlines', 'Singapore Airlines', 'AirAsia'],
    
    # Banks
    ['RBC', 'HSBC', 'Bank of America', 'JPMorgan Chase', 'Morgan Stanley', 'Goldman Sachs', 'ICICI Bank', 'Barclaycard', 'Chase', 'Bnp Paribas', 'Nordea', 'Wells Fargo', 'State Farm', 'Allstate', 'Charles Schwab', 'PNC', 'USAA', 'Metlife', 'Credit Suisse', 'Allianz', 'AXA'],
    
    # Retail
    ['Target', 'REI', 'Best Buy', 'Gamestop', 'Foot Locker', 'Neiman Marcus', 'Saks Fifth Avenue', 'Rite Aid', 'Office Depot', 'Dollar General', 'Meijer', 'Ulta Beauty'],
    
    # Supermarkets
    ['Walmart', 'Costco', 'Shoprite', 'Macy', 'Nordstrom', 'Finish Line'],
    
    # Oil and gas
    ['Shell', 'Total', 'BP', 'ExxonMobil', 'Chevron'],
    
    # Clothing
    ['Nike', 'Puma', 'Adidas', 'Ralph Lauren', 'Tommy Hilfiger', 'Lacoste', 'Hugo Boss', 'Converse', 'New Balance', 'H&M', 'Zara'],
    
    # Entertainment
    ['Netflix', 'Directv', 'Spotify', 'Walt Disney World', 'Paramount Pictures'],
    
    # Travel
    ['Airbnb', 'Tripadvisor', 'Booking.com', 'Club Med'],
    
    # Electronics and hardware
    ['Hewlett-Packard', 'Nokia', 'Nintendo', 'Huawei', 'Samsung Electronics', 'Sony', 'Samsung', 'Panasonic', 'Logitech', 'HP', 'Dell', 'Lenovo', 'Asus', 'Acer', 'Motorola', 'LG Electronics', 'Hitachi'],
    
    # Fast food
    ["Domino's Pizza", 'Yum! Brands', 'KFC', 'Subway', 'Chick-fil-A', 'Little Caesars Pizza', 'Pizza Hut', 'IHOP', 'Dairy Queen', 'Taco Bell', "McDonald's", 'Burger King'],
    
    # Luxury brands
    ['Coach', 'Burberry', 'Cartier', 'Louis Vuitton', 'Gucci', 'Chanel'],
    
    # Telecommunications
    ['Vodafone', 'Verizon', 'Airtel', 'Movistar', 'Comcast', 'AT&T'],
    
    # Worldwide associations
    ['Unicef', 'WWF', 'Rotary International', 'YMCA'],
    
    # Electrical appliances
    ['Philips', 'GE', 'Siemens', 'Honeywell', 'Rockwell Automation'],
    
    # Credit card
    ['Visa', 'Mastercard', 'American Express'],
    
    # Transport
    ['Fedex', 'UPS', 'DHL Express'],
    
    # Coffeehouses
    ['Starbucks', 'Tim Hortons', "Dunkin' Donuts"],
    
    # Tire manufacturers
    ['Bridgestone', 'Michelin', 'Pirelli'],
    
    # Energy/soft drinks
    ['Monster Energy', 'Red Bull', 'PepsiCo', 'Coca-Cola', 'Pepsi'],
    
    # Defense
    ['US Army', 'GSA', 'Lockheed Martin'],
    
    # Airplane manufacturers
    ['Boeing', 'Airbus'],
    
    # Online commerce
    ['Amazon.com', 'Alibaba Group', 'Ebay', 'Flipkart'],
    
    # Healthcare
    ['CVS Health', 'Kaiser Permanente', 'Mayo Clinic', 'UCLA Health', 'Sutter Health'],
    
    # Insurance
    ['Farmers Insurance', 'American Family Insurance', 'Travelers'],
    
    # Food company
    ['Nestle', 'Mars', 'General Mills', 'Sara Lee'],
    
    # Taxi
    ['Lyft', 'Uber'],
    
    # Car rental
    ['Hertz', 'Avis'],
    
    # Home improvement
    ['Home Depot', "Lowe's"],
    
    # Candy
    ['Wrigley', 'Hershey'],
    
    # Big Machinery
    ['John Deere', 'Caterpillar'],
    
    # Trains
    ['Amtrak', 'Virgin Trains'],
    
    # Money transfers
    ['Western Union', 'PayPal'],
    
    # Microprocessors
    ['AMD', 'Intel'],
    
    # Consulting
    ['Accenture', 'Deloitte'],
    
    # Consumer Goods Companies
    ['Unilever', 'Procter & Gamble'],
    
    # Entertainment production companies
    ['Disney', 'Warner Bros.'],
    
    # Camera
    ['Canon', 'Nikon'],
    
    # 3M
    ['3M']
]
