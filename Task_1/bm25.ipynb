# %%
from datetime import datetime
import numpy as np
import pandas as pd
import torch
from torch.optim.lr_scheduler import StepLR

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
train_df = pd.read_csv("/content/drive/MyDrive/test_new.csv")
val_df = pd.read_csv("/content/drive/MyDrive/val_pipeline.csv")

# %%
train_df
# Out:
#        Unnamed: 0 text_status  \
# 0               0    Has text
# 1               1    Has text
# 2               2    Has text
# 3               3    Has text
# 4               4    Has text
# ...           ...         ...
# 54326       54326    Has text
# 54327       54327    Has text
# 54328       54328    Has text
# 54329       54329    Has text
# 54330       54330    Has text
#
#                                                  content    languages  \
# 0      Congratulations to Pauletha Butts of <mention>...  ['ENGLISH']
# 1      #NetZeroHomes: learn the best way to get to ze...  ['ENGLISH']
# 2      Tournaments come and go, but the pictures are ...  ['ENGLISH']
# 3      Monster Hunter Rise Concept Art: Great Izuchi....  ['ENGLISH']
# 4      With our #SalesDevelopmentProgram, you'll lear...  ['ENGLISH']
# ...                                                  ...          ...
# 54326  Real Madrid Consider Huge Swap Deal For Arsena...  ['ENGLISH']
# ...

# %%
train_content = train_df["content"].values
val_content = val_df["content"].values

train_views = train_df["video_views"].values
val_views = val_df["video_views"].values

train_durations = train_df["video_duration"].values
val_durations = val_df["video_duration"].values

train_users = train_df["username"].values
val_users = val_df["username"].values

train_labels = train_df["likes"].values
val_labels = val_df["likes"].values

train_hasvids = np.array(train_df["video_url_status"].values != "Link does not exist")
val_hasvids = np.array(val_df["video_url_status"].values != "Link does not exist")

train_hasimgs = np.array(train_df["image_url_status"].values != "Link does not exist")
val_hasimgs = np.array(val_df["image_url_status"].values != "Link does not exist")

# train_dates = train_df['date'].values
# val_dates = val_df['date'].values

# %%
train_log_labels = []
for i in range(len(train_labels)):
  train_log_labels.append(np.log(1+train_labels[i]))

# %%
val_log_labels = []
for i in range(len(val_labels)):
  val_log_labels.append(np.log(1+val_labels[i]))

# %%
train_content_set_1 = []
train_labels_set_1 = []
train_views_set_1 = []
train_users_set_1 = []
train_duration_set_1 = []
train_hasvid_set_1 = []
train_hasimg_set_1 = []
train_hasgifs_set_1 = []
train_date_set_1 = []
train_captions_set_1 = []

train_content_set_2 = []
train_labels_set_2 = []
train_views_set_2 = []
train_users_set_2 = []
train_duration_set_2 = []
train_hasvid_set_2 = []
train_hasimg_set_2 = []
train_hasgifs_set_2 = []
train_date_set_2 = []
train_captions_set_2 = []

train_content_set_3 = []
train_labels_set_3 = []
train_views_set_3 = []
train_users_set_3 = []
train_duration_set_3 = []
train_hasvid_set_3 = []
train_hasimg_set_3 = []
train_hasgifs_set_3 = []
train_date_set_3 = []
train_captions_set_3 = []

train_content_set_4 = []
train_labels_set_4 = []
train_views_set_4 = []
train_users_set_4 = []
train_duration_set_4 = []
train_hasvid_set_4 = []
train_hasimg_set_4 = []
train_hasgifs_set_4 = []
train_date_set_4 = []
train_captions_set_4 = []

train_content_set_5 = []
train_labels_set_5 = []
train_views_set_5 = []
train_users_set_5 = []
train_duration_set_5 = []
train_hasvid_set_5 = []
train_hasimg_set_5 = []
train_hasgifs_set_5 = []
train_date_set_5 = []
train_captions_set_5 = []

val_content_set_1 = []
val_labels_set_1 = []
val_views_set_1 = []
val_users_set_1 = []
val_duration_set_1 = []
val_hasvid_set_1 = []
val_hasimg_set_1 = []
val_hasgifs_set_1 = []
val_date_set_1 = []
val_captions_set_1 = []

val_content_set_2 = []
val_labels_set_2 = []
val_views_set_2 = []
val_users_set_2 = []
val_duration_set_2 = []
val_hasvid_set_2 = []
val_hasimg_set_2 = []
val_hasgifs_set_2 = []
val_date_set_2 = []
val_captions_set_2 = []

val_content_set_3 = []
val_labels_set_3 = []
val_views_set_3 = []
val_users_set_3 = []
val_duration_set_3 = []
val_hasvid_set_3 = []
val_hasimg_set_3 = []
val_hasgifs_set_3 = []
val_date_set_3 = []
val_captions_set_3 = []

val_content_set_4 = []
val_labels_set_4 = []
val_views_set_4 = []
val_users_set_4 = []
val_duration_set_4 = []
val_hasvid_set_4 = []
val_hasimg_set_4 = []
val_hasgifs_set_4 = []
val_date_set_4 = []
val_captions_set_4 = []

val_content_set_5 = []
val_labels_set_5 = []
val_views_set_5 = []
val_users_set_5 = []
val_duration_set_5 = []
val_hasvid_set_5 = []
val_hasimg_set_5 = []
val_hasgifs_set_5 = []
val_date_set_5 = []
val_captions_set_5 = []

train_classes = []
val_classes = []
# train_1 = pd.DataFrame(columns = train_df.columns)
# train_2 = pd.DataFrame(columns = train_df.columns)
# train_3 = pd.DataFrame(columns = train_df.columns)
# train_4 = pd.DataFrame(columns = train_df.columns)

# %%
# train_1 = pd.DataFrame([train_df['content'].iloc[i] for i in range(len(train_log_labels)) if [(np.log(train_df['likes'].values) > np.log(75)) & (np.log(train_df['likes'].values) <= np.log(4000))]])
# train_2 = pd.DataFrame([train_df['content'].iloc[i] for i in range(len(train_log_labels)) if (train_df['likes'].apply(np.log) > np.log(75)) & (train_df['likes'].apply(np.log) <= np.log(4000))])
# train_3 = pd.DataFrame([train_df['content'].iloc[i] for i in range(len(train_log_labels)) if (train_log_labels[i].apply(np.log) > np.log(3000)) & (train_df['likes'].apply(np.log) <= np.log(12000))])
# train_4 = pd.DataFrame([train_df['content'].iloc[i] for i in range(len(train_log_labels)) if train_df['likes'].apply(np.log) > np.log(9000)])

# %%
for i in range(len(train_log_labels)):
  if train_log_labels[i] <= np.log(150):
    train_classes.append(0)
    train_content_set_1.append(train_content[i])
    train_views_set_1.append(train_views[i])
    train_users_set_1.append(train_users[i])
    train_labels_set_1.append(train_log_labels[i])
    train_duration_set_1.append(train_durations[i])
    train_hasvid_set_1.append(train_hasvids[i])
    train_hasimg_set_1.append(train_hasimgs[i])

  if train_log_labels[i] > np.log(75) and train_log_labels[i] <= np.log(4000):
    train_classes.append(1)
    train_content_set_2.append(train_content[i])
    train_views_set_2.append(train_views[i])
    train_users_set_2.append(train_users[i])
    train_labels_set_2.append(train_log_labels[i])
    train_duration_set_2.append(train_durations[i])
    train_hasvid_set_2.append(train_hasvids[i])
    train_hasimg_set_2.append(train_hasimgs[i])

  if train_log_labels[i] > np.log(3000) and train_log_labels[i] <= np.log(12000):
    train_classes.append(2)
    train_content_set_3.append(train_content[i])
    train_views_set_3.append(train_views[i])
    train_users_set_3.append(train_users[i])
    train_labels_set_3.append(train_log_labels[i])
    train_duration_set_3.append(train_durations[i])
    train_hasvid_set_3.append(train_hasvids[i])
    train_hasimg_set_3.append(train_hasimgs[i])

  if train_log_labels[i] > np.log(9000):
    train_classes.append(3)
    train_content_set_4.append(train_content[i])
    train_views_set_4.append(train_views[i])
    train_users_set_4.append(train_users[i])
    train_labels_set_4.append(train_log_labels[i])
    train_duration_set_4.append(train_durations[i])
    train_hasvid_set_4.append(train_hasvids[i])
    train_hasimg_set_4.append(train_hasimgs[i])

for i in range(len(val_log_labels)):
  if val_log_labels[i] <= np.log(150):
    val_classes.append(0)
    val_content_set_1.append(val_content[i])
    val_views_set_1.append(val_views[i])
    val_users_set_1.append(val_users[i])
    val_labels_set_1.append(val_log_labels[i])
    val_duration_set_1.append(val_durations[i])
    val_hasvid_set_1.append(val_hasvids[i])
    val_hasimg_set_1.append(val_hasimgs[i])

  if val_log_labels[i] > np.log(75) and val_log_labels[i] <= np.log(4000):
    val_classes.append(1)
    val_content_set_2.append(val_content[i])
    val_views_set_2.append(val_views[i])
    val_users_set_2.append(val_users[i])
    val_labels_set_2.append(val_log_labels[i])
    val_duration_set_2.append(val_durations[i])
    val_hasvid_set_2.append(val_hasvids[i])
    val_hasimg_set_2.append(val_hasimgs[i])
    # val_hasgifs_set_2.append(val_hasgifs[i])
    # val_date_set_2.append(val_dates[i])
    # val_captions_set_2.append(val_captions[i])

  if val_log_labels[i] > np.log(3000) and val_log_labels[i] <= np.log(12000):
    val_classes.append(2)
    val_content_set_3.append(val_content[i])
    val_views_set_3.append(val_views[i])
    val_users_set_3.append(val_users[i])
    val_labels_set_3.append(val_log_labels[i])
    val_duration_set_3.append(val_durations[i])
    val_hasvid_set_3.append(val_hasvids[i])
    val_hasimg_set_3.append(val_hasimgs[i])

  if val_log_labels[i] > np.log(9000):
    val_classes.append(3)
    val_content_set_4.append(val_content[i])
    val_views_set_4.append(val_views[i])
    val_users_set_4.append(val_users[i])
    val_labels_set_4.append(val_log_labels[i])
    val_duration_set_4.append(val_durations[i])
    val_hasvid_set_4.append(val_hasvids[i])
    val_hasimg_set_4.append(val_hasimgs[i])

# len(val_labels_set_3), len(val_labels_set_4),
len(train_labels_set_1), len(train_labels_set_2), len(train_labels_set_3), len(train_labels_set_4)
# Out:
# (33531, 25667, 1910, 766)

# %%
train_1.reset_index(drop=True, inplace=True)
train_2.reset_index(drop=True, inplace=True)
train_3.reset_index(drop=True, inplace=True)
train_4.reset_index(drop=True, inplace=True)

# %%
# !pip install rank_bm25

# %%
from rank_bm25 import BM25Okapi
import pandas as pd

df1 = pd.DataFrame({'content': train_content_set_1})
df2 = pd.DataFrame({'content': train_content_set_2})
df3 = pd.DataFrame({'content': train_content_set_3})
df4 = pd.DataFrame({'content': train_content_set_4})

tokenized_corpus1 = [text.split() for text in df1['content']]
tokenized_corpus2 = [text.split() for text in df2['content']]
tokenized_corpus3 = [text.split() for text in df3['content']]
tokenized_corpus4 = [text.split() for text in df4['content']]

bm25_model1 = BM25Okapi(tokenized_corpus1)
bm25_model2 = BM25Okapi(tokenized_corpus2)
bm25_model3 = BM25Okapi(tokenized_corpus3)
bm25_model4 = BM25Okapi(tokenized_corpus4)

new_text = "Your new text here"
scores1 = bm25_model1.get_scores(new_text.split())
scores2 = bm25_model2.get_scores(new_text.split())
scores3 = bm25_model3.get_scores(new_text.split())
scores4 = bm25_model4.get_scores(new_text.split())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
test_predictions = model.predict(dtest)
test_text_predictions = text_regressor.predict(X_test_text)
test_combined_features = np.column_stack((test_text_predictions, test_predictions))
predictions = meta_model.predict(test_combined_features)
