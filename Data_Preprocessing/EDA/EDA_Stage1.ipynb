# %% [markdown]
# ## Setup dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q pycld2

# %%
import pandas as pd
import numpy as np
import pycld2
import re
import requests
from datetime import datetime

# %%
train = pd.read_csv('/content/drive/MyDrive/test.csv')
train
# Out:
#            id                 date  likes  \
# 0           5  2018-10-19 14:30:46     41
# 1          12  2020-11-18 00:07:02      0
# 2          23  2018-09-11 14:23:02    120
# 3          31  2020-11-10 03:00:26    567
# 4          32  2018-11-29 22:11:56      1
# ...       ...                  ...    ...
# 59326  299981  2019-11-30 12:40:07      0
# 59327  299982  2018-07-22 13:08:00    144
# 59328  299986  2019-10-09 17:59:33      0
# 59329  299991  2020-12-17 19:45:01    174
# 59330  300000  2018-08-26 01:19:09    714
#
#                                                  content        username  \
# 0      Congratulations to Pauletha Butts of <mention>...           BGISD
# 1      #NetZeroHomes: learn the best way to get to ze...  MitsubishiHVAC
# 2      Tournaments come and go, but the pictures are ...      GettySport
# 3      Monster Hunter Rise Concept Art: Great Izuchi....       MHinfo_en
# 4      With our #SalesDevelopmentProgram, you'll lear...   UnitedRentals
# ...                                                  ...             ...
# 59326  Real Madrid Consider Huge Swap Deal For Arsena...  IndependentNGR
# 59327  The founding of this <mention> club and the ro...          Rotary
# 59328  NDDC Still Implementing 2018 Budget As FG, Oth...  IndependentNGR
# 59329  I'm incredibly pumped for #XFL alum <mention>\...   PatMcAfeeShow
# 59330  In 1967, he was shot down over Vietnam. By 200...            cnni
#
#                                                    media      inferred company
# 0      [Photo(previewUrl='https://pbs.twimg.com/media...           independent
# 1      [Photo(previewUrl='https://pbs.twimg.com/media...                 trane
# 2      [Photo(previewUrl='https://pbs.twimg.com/media...          getty images
# 3      [Photo(previewUrl='https://pbs.twimg.com/media...               monster
# 4      [Photo(previewUrl='https://pbs.twimg.com/media...        united rentals
# ...                                                  ...                   ...
# 59326  [Photo(previewUrl='https://pbs.twimg.com/media...           independent
# 59327  [Video(thumbnailUrl='https://pbs.twimg.com/amp...  rotary international
# 59328  [Photo(previewUrl='https://pbs.twimg.com/media...           independent
# 59329  [Video(thumbnailUrl='https://pbs.twimg.com/amp...                mcafee
# 59330  [Video(thumbnailUrl='https://pbs.twimg.com/ext...                   cnn
#
# [59331 rows x 7 columns]

# %%
column = ['text_status', 'text', 'languages', 'image_url_status', 'image_url', 'video_thumbnail_status', 'video_thumbnail_url', 'video_url_status', 'video_url', 'video_bitrate', 'video_duration', 'video_views', 'gif_thumbnail_status', 'gif_thumbnail_url', 'gif_url_status', 'gif_url', 'gif_bitrate', 'year', 'month', 'day_of_year', 'day_of_week', 'date', 'username', 'inferred company', 'likes']
eda = pd.DataFrame(columns = column)

# %% [markdown]
# ## Setup funtions

# %%
def detect_languages(text):
  langs = []
  _, _, details = pycld2.detect(text)
  for lang in details:
    # check confidence of each language before reporting (atleast 50%)
    if(lang[2]>=50):
      langs.append(lang[0])
  return langs if langs!=[] else ['Unknown']

# %%
def check_link(url):
  try:
    response = requests.head(url)
    if response.status_code >= 200 and response.status_code < 400:
      return ("Link exists and is accessible")
    else:
      return ("Link exists but is not accessible")
  except requests.ConnectionError:
    return ("Error while accessing the link")

# %%
def time(datetime_str):
  dt_object = datetime.strptime(datetime_str, "%Y-%m-%d %H:%M:%S")

  year = dt_object.year
  month = dt_object.strftime("%B")
  day_of_year = dt_object.timetuple().tm_yday
  day_of_week = dt_object.strftime('%A')

  return [year, month, day_of_year, day_of_week]

# %%
def photo_gif_param(input_string):
    photo_pattern = r"Photo\(previewUrl='(.*?)', fullUrl='(.*?)'\)"
    gif_pattern = r"Gif\(thumbnailUrl='(.*?)', variants=\[VideoVariant\(contentType='video/mp4', url='(.*?)', bitrate=(\d+)\)\]\)"

    photos = re.findall(photo_pattern, input_string)
    gifs = re.findall(gif_pattern, input_string)

    photos_df = pd.DataFrame(photos, columns=['photo_preview_url', 'photo_full_url'])
    gifs_df = pd.DataFrame(gifs, columns=['gif_thumbnail_url', 'gif_url', 'gif_bitrate'])

    return [photos_df, gifs_df]

def video_param(input_string):
    # Initialize variables to track the minimum bitrate and its corresponding video URL
    min_bitrate = float('inf')
    min_bitrate_video_url = None

    thumbnail_url_match = re.search(r"thumbnailUrl='(.*?)'", input_string)
    if thumbnail_url_match:
        thumbnail_url = thumbnail_url_match.group(1)

    video_urls_and_bitrates = re.findall(r"url='(.*?)', bitrate=(\d+|None)", input_string)
    for video_url, bitrate_str in video_urls_and_bitrates:
        bitrate = int(bitrate_str) if bitrate_str != "None" else float('inf')
        if bitrate < min_bitrate:
            min_bitrate = bitrate
            min_bitrate_video_url = video_url

    duration_match = re.search(r"duration=(\d+\.\d+)", input_string)
    if duration_match:
        duration = float(duration_match.group(1))
    else:
        duration = "Does not exist"

    views_match = re.search(r"views=(\d+)", input_string)
    if views_match:
        views = int(views_match.group(1))
    else:
        views = "Does not exist"

    return [thumbnail_url, min_bitrate_video_url, min_bitrate, duration, views]

# %% [markdown]
# ## Analyse the dataset

# %%
# all tweets have some text
train['content'].isna().sum()
# Out:
# 0

# %%
dataset1 = pd.read_csv('/content/drive/MyDrive/val_full.csv')
# dataset1 = pd.DataFrame(columns = column)

# %%
dataset1
# Out:
#       text_status                                               text  \
# 0        Has text  Congratulations to Pauletha Butts of <mention>...
# 1        Has text  #NetZeroHomes: learn the best way to get to ze...
# 2        Has text  Tournaments come and go, but the pictures are ...
# 3        Has text  Monster Hunter Rise Concept Art: Great Izuchi....
# 4        Has text  With our #SalesDevelopmentProgram, you'll lear...
# ...           ...                                                ...
# 59326    Has text  Real Madrid Consider Huge Swap Deal For Arsena...
# 59327    Has text  The founding of this <mention> club and the ro...
# 59328    Has text  NDDC Still Implementing 2018 Budget As FG, Oth...
# 59329    Has text  I'm incredibly pumped for #XFL alum <mention>\...
# 59330    Has text  In 1967, he was shot down over Vietnam. By 200...
#
#          languages               image_url_status  \
# 0      ['ENGLISH']  Link exists and is accessible
# 1      ['ENGLISH']  Link exists and is accessible
# 2      ['ENGLISH']  Link exists and is accessible
# 3      ['ENGLISH']  Link exists and is accessible
# 4      ['ENGLISH']  Link exists and is accessible
# ...            ...                            ...
# 59326  ['ENGLISH']  Link exists and is accessible
# 59327  ['ENGLISH']            Link does not exist
# 59328  ['ENGLISH']  Link exists and is accessible
# 59329  ['ENGLISH']            Link does not exist
# 59330  ['ENGLISH']            Link does not exist
#
#                                                image_url  \
# 0      https://pbs.twimg.com/media/Dp4L0cSUcAAh9JG?fo...
# 1      https://pbs.twimg.com/media/EnEIA1NXcAQIJw8?fo...
# 2      https://pbs.twimg.com/media/Dm0dpR7X0AEHCvO?fo...
# 3      https://pbs.twimg.com/media/Embi-1aUYAEK4hb?fo...
# 4      https://pbs.twimg.com/media/DtM-hi2UwAAWH2i?fo...
# ...                                                  ...
# 59326  https://pbs.twimg.com/media/EKnxk0iU4AEiUYC?fo...
# 59327                               Image does not exist
# 59328  https://pbs.twimg.com/media/EGdIA8TVAAEPa5N?fo...
# 59329                               Image does not exist
# 59330                               Image does not exist
#
#               video_thumbnail_status  \
# 0                Link does not exist
# 1                Link does not exist
# 2                Link does not exist
# 3                Link does not exist
# 4                Link does not exist
# ...                              ...
# 59326            Link does not exist
# 59327  Link exists and is accessible
# 59328            Link does not exist
# 59329  Link exists and is accessible
# 59330  Link exists and is accessible
#
#                                      video_thumbnail_url  \
# 0                         Video thumbnail does not exist
# 1                         Video thumbnail does not exist
# 2                         Video thumbnail does not exist
# 3                         Video thumbnail does not exist
# 4                         Video thumbnail does not exist
# ...                                                  ...
# 59326                     Video thumbnail does not exist
# 59327  https://pbs.twimg.com/amplify_video_thumb/1009...
# 59328                     Video thumbnail does not exist
# 59329  https://pbs.twimg.com/amplify_video_thumb/1339...
# 59330  https://pbs.twimg.com/ext_tw_video_thumb/10335...
#
#                     video_url_status  \
# 0                Link does not exist
# 1                Link does not exist
# 2                Link does not exist
# 3                Link does not exist
# 4                Link does not exist
# ...                              ...
# 59326            Link does not exist
# 59327  Link exists and is accessible
# 59328            Link does not exist
# 59329  Link exists and is accessible
# 59330  Link exists and is accessible
#
#                                                video_url   video_bitrate  ...  \
# 0                                   Video does not exist  Does not exist  ...
# 1                                   Video does not exist  Does not exist  ...
# 2                                   Video does not exist  Does not exist  ...
# 3                                   Video does not exist  Does not exist  ...
# 4                                   Video does not exist  Does not exist  ...
# ...                                                  ...             ...  ...
# 59326                               Video does not exist  Does not exist  ...
# 59327  https://video.twimg.com/amplify_video/10092287...          320000  ...
# 59328                               Video does not exist  Does not exist  ...
# 59329  https://video.twimg.com/amplify_video/13396572...          288000  ...
# 59330  https://video.twimg.com/ext_tw_video/103352404...          256000  ...
#
#                   gif_url     gif_bitrate  year      month day_of_year  \
# 0      GIF does not exist  Does not exist  2018    October         292
# 1      GIF does not exist  Does not exist  2020   November         323
# 2      GIF does not exist  Does not exist  2018  September         254
# 3      GIF does not exist  Does not exist  2020   November         315
# 4      GIF does not exist  Does not exist  2018   November         333
# ...                   ...             ...   ...        ...         ...
# 59326  GIF does not exist  Does not exist  2019   November         334
# 59327  GIF does not exist  Does not exist  2018       July         203
# 59328  GIF does not exist  Does not exist  2019    October         282
# 59329  GIF does not exist  Does not exist  2020   December         352
# 59330  GIF does not exist  Does not exist  2018     August         238
#
#       day_of_week                 date        username      inferred company  \
# 0          Friday  2018-10-19 14:30:46           BGISD           independent
# 1       Wednesday  2020-11-18 00:07:02  MitsubishiHVAC                 trane
# 2         Tuesday  2018-09-11 14:23:02      GettySport          getty images
# 3         Tuesday  2020-11-10 03:00:26       MHinfo_en               monster
# 4        Thursday  2018-11-29 22:11:56   UnitedRentals        united rentals
# ...           ...                  ...             ...                   ...
# 59326    Saturday  2019-11-30 12:40:07  IndependentNGR           independent
# 59327      Sunday  2018-07-22 13:08:00          Rotary  rotary international
# 59328   Wednesday  2019-10-09 17:59:33  IndependentNGR           independent
# 59329    Thursday  2020-12-17 19:45:01   PatMcAfeeShow                mcafee
# 59330      Sunday  2018-08-26 01:19:09            cnni                   cnn
#
#        likes
# 0         41
# 1          0
# 2        120
# 3        567
# 4          1
# ...      ...
# 59326      0
# 59327    144
# 59328      0
# 59329    174
# 59330    714
#
# [59331 rows x 25 columns]

# %%
l = len(train)
m = 59201

for i in range(m,l):
    eda.at[i-m, 'languages'] = detect_languages(train.at[i,'content'])

    dt = time(train.at[i,'date'])
    eda.at[i-m, 'year'] = dt[0]
    eda.at[i-m, 'month'] = dt[1]
    eda.at[i-m, 'day_of_year'] = dt[2]
    eda.at[i-m, 'day_of_week'] = dt[3]

    eda.at[i-m,'text'] = train.at[i,'content']
    eda.at[i-m,'date'] = train.at[i,'date']
    eda.at[i-m,'username'] = train.at[i,'username']
    eda.at[i-m,'inferred company'] = train.at[i,'inferred company']
    eda.at[i-m,'likes'] = train.at[i,'likes']

    img_gif = photo_gif_param(train.at[i,'media'])
    if(img_gif[0].empty and img_gif[1].empty):
        vid = video_param(train.at[i, 'media'])

        eda.at[i-m, 'video_thumbnail_url'] = vid[0]
        eda.at[i-m, 'video_url'] = vid[1]
        eda.at[i-m, 'video_thumbnail_status'] = check_link(vid[0]) if vid[0]!="" else "Link does not exist"
        eda.at[i-m, 'video_url_status'] = check_link(vid[1]) if vid[1]!="" else "Link does not exist"
        eda.at[i-m, 'video_bitrate'] = vid[2] if vid[2]!=0 else "Does not exist"
        eda.at[i-m, 'video_duration'] = vid[3] if vid[3]!=0.0 else "Does not exist"
        eda.at[i-m, 'video_views'] = vid[4] if vid[4]!=0 else "Does not exist"

        eda.at[i-m, 'image_url_status'] = "Link does not exist"
        eda.at[i-m, 'image_url'] = "Image does not exist"
        eda.at[i-m, 'gif_thumbnail_status'] = "Link does not exist"
        eda.at[i-m, 'gif_thumbnail_url'] = "GIF thumbnail does not exist"
        eda.at[i-m, 'gif_url_status'] = "Link does not exist"
        eda.at[i-m, 'gif_url'] = "GIF does not exist"
        eda.at[i-m, 'gif_bitrate'] = "Does not exist"

    else:
        eda.at[i-m, 'video_thumbnail_status'] = "Link does not exist"
        eda.at[i-m, 'video_url_status'] = "Link does not exist"
        eda.at[i-m, 'video_thumbnail_url'] = "Video thumbnail does not exist"
        eda.at[i-m, 'video_url'] = "Video does not exist"
        eda.at[i-m, 'video_bitrate'] = "Does not exist"
        eda.at[i-m, 'video_duration'] = "Does not exist"
        eda.at[i-m, 'video_views'] = "Does not exist"

        if(img_gif[0].empty):
          eda.at[i-m, 'image_url_status'] = "Link does not exist"
          eda.at[i-m, 'image_url'] = "Image does not exist"

          eda.at[i-m, 'gif_thumbnail_url'] = img_gif[1]['gif_thumbnail_url'].values[0]
          eda.at[i-m, 'gif_url'] = img_gif[1]['gif_url'].values[0]
          eda.at[i-m, 'gif_thumbnail_status'] = check_link(img_gif[1]['gif_thumbnail_url'].values[0])
          eda.at[i-m, 'gif_url_status'] = check_link(img_gif[1]['gif_url'].values[0])
          eda.at[i-m, 'gif_bitrate'] = img_gif[1]['gif_bitrate']

        else:
          eda.at[i-m, 'image_url_status'] = check_link(img_gif[0]['photo_preview_url'].values[0])
          eda.at[i-m, 'image_url'] = img_gif[0]['photo_preview_url'].values[0]

          eda.at[i-m, 'gif_thumbnail_status'] = "Link does not exist"
          eda.at[i-m, 'gif_thumbnail_url'] = "GIF thumbnail does not exist"
          eda.at[i-m, 'gif_url_status'] = "Link does not exist"
          eda.at[i-m, 'gif_url'] = "GIF does not exist"
          eda.at[i-m, 'gif_bitrate'] = "Does not exist"

    if(i%10==0):
        print((i),'generated')
        eda['text_status'] = "Has text"
        # dataset1 = eda
        dataset1 = pd.concat([dataset1, eda], ignore_index=True)
        # dataset1.to_csv('/content/drive/MyDrive/train_full.csv', index=False)
        # dataset1.to_csv('/content/drive/MyDrive/val_full.csv', index=False)
        dataset1.to_csv('/content/drive/MyDrive/test_full.csv', index=False)

        column = ['text_status', 'text', 'languages', 'image_url_status', 'image_url', 'video_thumbnail_status', 'video_thumbnail_url', 'video_url_status', 'video_url', 'video_bitrate', 'video_duration', 'video_views', 'gif_thumbnail_status', 'gif_thumbnail_url', 'gif_url_status', 'gif_url', 'gif_bitrate', 'year', 'month', 'day_of_year', 'day_of_week', 'date', 'username', 'inferred company', 'likes']
        eda = pd.DataFrame(columns = column)
# Out:
# 59210 generated
# 59220 generated
# 59230 generated
# 59240 generated
# 59250 generated
# 59260 generated
# 59270 generated
# 59280 generated
# 59290 generated
# 59300 generated
# 59310 generated
# 59320 generated
# 59330 generated

# %%
dataset1
# Out:
#       text_status                                               text  \
# 0        Has text  Congratulations to Pauletha Butts of <mention>...
# 1        Has text  #NetZeroHomes: learn the best way to get to ze...
# 2        Has text  Tournaments come and go, but the pictures are ...
# 3        Has text  Monster Hunter Rise Concept Art: Great Izuchi....
# 4        Has text  With our #SalesDevelopmentProgram, you'll lear...
# ...           ...                                                ...
# 59326    Has text  Real Madrid Consider Huge Swap Deal For Arsena...
# 59327    Has text  The founding of this <mention> club and the ro...
# 59328    Has text  NDDC Still Implementing 2018 Budget As FG, Oth...
# 59329    Has text  I'm incredibly pumped for #XFL alum <mention>\...
# 59330    Has text  In 1967, he was shot down over Vietnam. By 200...
#
#        languages               image_url_status  \
# 0      [ENGLISH]  Link exists and is accessible
# 1      [ENGLISH]  Link exists and is accessible
# 2      [ENGLISH]  Link exists and is accessible
# 3      [ENGLISH]  Link exists and is accessible
# 4      [ENGLISH]  Link exists and is accessible
# ...          ...                            ...
# 59326  [ENGLISH]  Link exists and is accessible
# 59327  [ENGLISH]            Link does not exist
# 59328  [ENGLISH]  Link exists and is accessible
# 59329  [ENGLISH]            Link does not exist
# 59330  [ENGLISH]            Link does not exist
#
#                                                image_url  \
# 0      https://pbs.twimg.com/media/Dp4L0cSUcAAh9JG?fo...
# 1      https://pbs.twimg.com/media/EnEIA1NXcAQIJw8?fo...
# 2      https://pbs.twimg.com/media/Dm0dpR7X0AEHCvO?fo...
# 3      https://pbs.twimg.com/media/Embi-1aUYAEK4hb?fo...
# 4      https://pbs.twimg.com/media/DtM-hi2UwAAWH2i?fo...
# ...                                                  ...
# 59326  https://pbs.twimg.com/media/EKnxk0iU4AEiUYC?fo...
# 59327                               Image does not exist
# 59328  https://pbs.twimg.com/media/EGdIA8TVAAEPa5N?fo...
# 59329                               Image does not exist
# 59330                               Image does not exist
#
#               video_thumbnail_status  \
# 0                Link does not exist
# 1                Link does not exist
# 2                Link does not exist
# 3                Link does not exist
# 4                Link does not exist
# ...                              ...
# 59326            Link does not exist
# 59327  Link exists and is accessible
# 59328            Link does not exist
# 59329  Link exists and is accessible
# 59330  Link exists and is accessible
#
#                                      video_thumbnail_url  \
# 0                         Video thumbnail does not exist
# 1                         Video thumbnail does not exist
# 2                         Video thumbnail does not exist
# 3                         Video thumbnail does not exist
# 4                         Video thumbnail does not exist
# ...                                                  ...
# 59326                     Video thumbnail does not exist
# 59327  https://pbs.twimg.com/amplify_video_thumb/1009...
# 59328                     Video thumbnail does not exist
# 59329  https://pbs.twimg.com/amplify_video_thumb/1339...
# 59330  https://pbs.twimg.com/ext_tw_video_thumb/10335...
#
#                     video_url_status  \
# 0                Link does not exist
# 1                Link does not exist
# 2                Link does not exist
# 3                Link does not exist
# 4                Link does not exist
# ...                              ...
# 59326            Link does not exist
# 59327  Link exists and is accessible
# 59328            Link does not exist
# 59329  Link exists and is accessible
# 59330  Link exists and is accessible
#
#                                                video_url   video_bitrate  ...  \
# 0                                   Video does not exist  Does not exist  ...
# 1                                   Video does not exist  Does not exist  ...
# 2                                   Video does not exist  Does not exist  ...
# 3                                   Video does not exist  Does not exist  ...
# 4                                   Video does not exist  Does not exist  ...
# ...                                                  ...             ...  ...
# 59326                               Video does not exist  Does not exist  ...
# 59327  https://video.twimg.com/amplify_video/10092287...          320000  ...
# 59328                               Video does not exist  Does not exist  ...
# 59329  https://video.twimg.com/amplify_video/13396572...          288000  ...
# 59330  https://video.twimg.com/ext_tw_video/103352404...          256000  ...
#
#                   gif_url     gif_bitrate  year      month day_of_year  \
# 0      GIF does not exist  Does not exist  2018    October         292
# 1      GIF does not exist  Does not exist  2020   November         323
# 2      GIF does not exist  Does not exist  2018  September         254
# 3      GIF does not exist  Does not exist  2020   November         315
# 4      GIF does not exist  Does not exist  2018   November         333
# ...                   ...             ...   ...        ...         ...
# 59326  GIF does not exist  Does not exist  2019   November         334
# 59327  GIF does not exist  Does not exist  2018       July         203
# 59328  GIF does not exist  Does not exist  2019    October         282
# 59329  GIF does not exist  Does not exist  2020   December         352
# 59330  GIF does not exist  Does not exist  2018     August         238
#
#       day_of_week                 date        username      inferred company  \
# 0          Friday  2018-10-19 14:30:46           BGISD           independent
# 1       Wednesday  2020-11-18 00:07:02  MitsubishiHVAC                 trane
# 2         Tuesday  2018-09-11 14:23:02      GettySport          getty images
# 3         Tuesday  2020-11-10 03:00:26       MHinfo_en               monster
# 4        Thursday  2018-11-29 22:11:56   UnitedRentals        united rentals
# ...           ...                  ...             ...                   ...
# 59326    Saturday  2019-11-30 12:40:07  IndependentNGR           independent
# 59327      Sunday  2018-07-22 13:08:00          Rotary  rotary international
# 59328   Wednesday  2019-10-09 17:59:33  IndependentNGR           independent
# 59329    Thursday  2020-12-17 19:45:01   PatMcAfeeShow                mcafee
# 59330      Sunday  2018-08-26 01:19:09            cnni                   cnn
#
#       likes
# 0        41
# 1         0
# 2       120
# 3       567
# 4         1
# ...     ...
# 59326     0
# 59327   144
# 59328     0
# 59329   174
# 59330   714
#
# [59331 rows x 25 columns]

# %%
train.iloc[-1]
# Out:
# id                                                             300000
# date                                              2018-08-26 01:19:09
# likes                                                             714
# content             In 1967, he was shot down over Vietnam. By 200...
# username                                                         cnni
# media               [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# inferred company                                                  cnn
# Name: 59330, dtype: object

# %%
j = dataset1.loc[dataset1['gif_bitrate'].astype(str) == "0    0\nName: gif_bitrate, dtype: object"].index
for i in j:
  dataset1.at[i, 'gif_bitrate'] = 0

# %%
# dataset1.to_csv('/content/drive/MyDrive/train_full.csv', index=False)
dataset1.to_csv('/content/drive/MyDrive/test_full.csv', index=False)
